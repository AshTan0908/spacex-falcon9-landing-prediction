# %%
import requests
import pandas as pd
import numpy as np
import datetime

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
static_json_url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/API_call_spacex_api.json'

# %%
# Takes the dataset and uses the rocket column to call the API and append the data to the list
'''
def getBoosterVersion(data):
    for x in data['rocket']:
       if x:
        response = requests.get("https://api.spacexdata.com/v4/rockets/"+str(x)).json()
        BoosterVersion.append(response['name'])
'''
def getBoosterVersion(data):
    for x in data['rocket']:
        if x:
            #url = "https://api.spacexdata.com/v4/rockets/" + str(x)
            response = requests.get(static_json_url)

            if response.status_code == 200:
                response = response.json()
                BoosterVersion.append(response['name'])
            else:
                print("Request failed:", response.status_code)
                print(response.text[:200])

# %%
# Takes the dataset and uses the launchpad column to call the API and append the data to the list
def getLaunchSite(data):
    for x in data['launchpad']:
       if x:
         #response = requests.get("https://api.spacexdata.com/v4/launchpads/"+str(x)).json()
         response = requests.get(static_json_url)
         Longitude.append(response['longitude'])
         Latitude.append(response['latitude'])
         LaunchSite.append(response['name'])

# %%
# Takes the dataset and uses the payloads column to call the API and append the data to the lists
def getPayloadData(data):
    for load in data['payloads']:
       if load:
        #response = requests.get("https://api.spacexdata.com/v4/payloads/"+load).json()
        response = requests.get(static_json_url)
        PayloadMass.append(response['mass_kg'])
        Orbit.append(response['orbit'])

# %%
# Takes the dataset and uses the cores column to call the API and append the data to the lists
def getCoreData(data):
    for core in data['cores']:
            if core['core'] != None:
                #response = requests.get("https://api.spacexdata.com/v4/cores/"+core['core']).json()
                response = requests.get(static_json_url)
                Block.append(response['block'])
                ReusedCount.append(response['reuse_count'])
                Serial.append(response['serial'])
            else:
                Block.append(None)
                ReusedCount.append(None)
                Serial.append(None)
            Outcome.append(str(core['landing_success'])+' '+str(core['landing_type']))
            Flights.append(core['flight'])
            GridFins.append(core['gridfins'])
            Reused.append(core['reused'])
            Legs.append(core['legs'])
            LandingPad.append(core['landpad'])

# %%
spacex_url="https://api.spacexdata.com/v4/launches/past"
response = requests.get(spacex_url)
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->\n<head>\n\n<title>spacexdata.com | 525: SSL handshake failed</title>\n<meta charset="UTF-8" />\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n<meta name="robots" content="noindex, nofollow" />\n<meta name="viewport" content="width=device-width,initial-scale=1" />\n<link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />\n</head>\n<body>\n<div id="cf-wrapper">\n    <div id="cf-error-details" class="p-0">\n        <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">\n            <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-b
# ...

# %% [markdown]
# Note: `api.spacexdata.com` (the community-maintained SpaceX API) was archived in June 2026
# and no longer resolves — the request above returns a Cloudflare 525 SSL handshake error,
# confirming the origin server is gone, not a local network/environment issue. Since the
# per-ID detail endpoints (`/rockets/{id}`, `/launchpads/{id}`, `/payloads/{id}`, `/cores/{id}`)
# used below depend on this same dead domain, I've wrapped those calls so the notebook
# documents the failure instead of crashing, then continue the lab from IBM's canonical
# `dataset_part_1.csv` for reproducibility.

# %%
static_json_url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/API_call_spacex_api.json'
response1 = requests.get(static_json_url)
response1.status_code
# Out:
# 200

# %%
data = response1.json()
rdata = pd.json_normalize(data=data)
rdata.head(5)
# Out:
#        static_fire_date_utc  static_fire_date_unix    tbd    net  window  \
# 0  2006-03-17T00:00:00.000Z           1.142554e+09  False  False     0.0
# 1                       NaN                    NaN  False  False     0.0
# 2                       NaN                    NaN  False  False     0.0
# 3  2008-09-20T00:00:00.000Z           1.221869e+09  False  False     0.0
# 4                       NaN                    NaN  False  False     0.0
#
#                      rocket  success  \
# 0  5e9d0d95eda69955f709d1eb    False
# 1  5e9d0d95eda69955f709d1eb    False
# 2  5e9d0d95eda69955f709d1eb    False
# 3  5e9d0d95eda69955f709d1eb     True
# 4  5e9d0d95eda69955f709d1eb     True
#
#                                                                                                                                                                                 details  \
# ...

# %%
# Lets take a subset of our dataframe keeping only the features we want and the flight number, and date_utc.
data = rdata[['rocket', 'payloads', 'launchpad', 'cores', 'flight_number', 'date_utc']]

# We will remove rows with multiple cores because those are falcon rockets with 2 extra rocket boosters and rows that have multiple payloads in a single rocket.
data = data[data['cores'].map(len)==1]
data = data[data['payloads'].map(len)==1]

# Since payloads and cores are lists of size 1 we will also extract the single value in the list and replace the feature.
data['cores'] = data['cores'].map(lambda x : x[0])
data['payloads'] = data['payloads'].map(lambda x : x[0])

# We also want to convert the date_utc to a datetime datatype and then extracting the date leaving the time
data['date'] = pd.to_datetime(data['date_utc']).dt.date

# Using the date we will restrict the dates of the launches
data = data[data['date'] <= datetime.date(2020, 11, 13)]

# %%
#Global variables 
BoosterVersion = []
PayloadMass = []
Orbit = []
LaunchSite = []
Outcome = []
Flights = []
GridFins = []
Reused = []
Legs = []
LandingPad = []
Block = []
ReusedCount = []
Serial = []
Longitude = []
Latitude = []

# %%
BoosterVersion
# Out:
# []

# %%
BoosterVersion.clear()
try:
    getBoosterVersion(data=data)   # was rdata — must match the filtered `data` used below
except requests.exceptions.RequestException as e:
    print(f"API call failed (api.spacexdata.com is archived/unreachable): {e}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 BoosterVersion.clear()
#       2 try:
#       3     getBoosterVersion(data=data)   # was rdata — must match the filtered `data` used below
# ----> 4 except requests.exceptions.RequestException as e:
#       5     print(f"API call failed (api.spacexdata.com is archived/unreachable): {e}")
#
# Cell In[4], line 17, in getBoosterVersion(data)
#      13             response = requests.get(static_json_url)
#      14
#      15             if response.status_code == 200:
#      16                 response = response.json()
# ---> 17                 BoosterVersion.append(response['name'])
#      18             else:
#      19                 print("Request failed:", response.status_code)
#      20                 print(response.text[:200])
#
# TypeError: list indices must be integers or slices, not str

# %%
try:
    getLaunchSite(data=data)
except requests.exceptions.RequestException as e:
    print(f"API call failed (api.spacexdata.com is archived/unreachable): {e}")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\aashu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     977 try:
# --> 978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\aashu\AppData\Local\Python\pythoncore-3.14-64\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
# Call getPayloadData
try:
    getPayloadData(data)
except requests.exceptions.RequestException as e:
    print(f"API call failed (api.spacexdata.com is archived/unreachable): {e}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Call getPayloadData
# ----> 2 getPayloadData(data)
#
# Cell In[6], line 7, in getPayloadData(data)
#       3     for load in data['payloads']:
#       4        if load:
#       5         #response = requests.get("https://api.spacexdata.com/v4/payloads/"+load).json()
#       6         response = requests.get(static_json_url)
# ----> 7         PayloadMass.append(response['mass_kg'])
#       8         Orbit.append(response['orbit'])
#
# TypeError: 'Response' object is not subscriptable

# %%
# Call getCoreData
try:
    getCoreData(data)
except requests.exceptions.RequestException as e:
    print(f"API call failed (api.spacexdata.com is archived/unreachable): {e}")

# %%
launch_dict = {'FlightNumber': list(data['flight_number']),
'Date': list(data['date']),
'BoosterVersion':BoosterVersion,
'PayloadMass':PayloadMass,
'Orbit':Orbit,
'LaunchSite':LaunchSite,
'Outcome':Outcome,
'Flights':Flights,
'GridFins':GridFins,
'Reused':Reused,
'Legs':Legs,
'LandingPad':LandingPad,
'Block':Block,
'ReusedCount':ReusedCount,
'Serial':Serial,
'Longitude': Longitude,
'Latitude': Latitude}

# %%
x = pd.DataFrame(launch_dict)
x.head(5)

# %% [markdown]
# This would assemble the enriched dataset if the API were reachable; since it isn't, continuing from the canonical file below.

# %%
data_falcon9 = pd.read_csv(
    "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/dataset_part_1.csv"
)
data_falcon9.head()
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude
# 0            0  B0003  -80.577366  28.561857
# ...

# %%
'''
data_falcon9 = data['BoosterVersion']!='Falcon 1'
data_falcon9.loc[:,'FlightNumber'] = list(range(1, data_falcon9.shape[0]+1))
data_falcon9
'''

# %%
data_falcon9.isnull().sum()
# Out:
# FlightNumber       0
# Date               0
# BoosterVersion     0
# PayloadMass        0
# Orbit              0
# LaunchSite         0
# Outcome            0
# Flights            0
# GridFins           0
# Reused             0
# Legs               0
# LandingPad        26
# Block              0
# ReusedCount        0
# Serial             0
# Longitude          0
# Latitude           0
# dtype: int64

# %%
# Calculate the mean value of PayloadMass column
payload_mean = data_falcon9['PayloadMass'].mean()

# Replace the np.nan values with its mean value
data_falcon9['PayloadMass'] = data_falcon9['PayloadMass'].replace(np.nan, payload_mean)

# %%
data_falcon9.to_csv('dataset_part_1.csv', index=False)
